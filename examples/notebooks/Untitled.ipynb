# %%
import torch
decay_rate=0.5
latent_dim = 20
target_decay = torch.exp(-decay_rate * torch.arange(latent_dim, dtype=torch.float32))
target_decay = torch.nn.functional.normalize(target_decay, p=1.0, dim=0)
import matplotlib.pyplot as plt
plt.plot(target_decay)

# %%
F.normalize(target_decay, p=1.0, dim=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 F.normalize(target_decay, p=1.0, dim=0)
#
# NameError: name 'F' is not defined
