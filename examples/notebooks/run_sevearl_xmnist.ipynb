# %%
# available_datasets = {
#     "breastmnist": "BreastMNIST",
#     "dermamnist": "Dermamnist",
#     "octmnist": "OCTMNIST",
#     "organamnist": "OrganAMNIST",
#     "organcmnist": "OrganCMNIST",
#     "organsmnist": "OrganSMNIST",
#     "pathmnist": "PathMNIST",
#     "pneumoniamnist": "PneumoniaMNIST",
#     "retinamnist": "RetinaMNIST",
#     "bloodmnist": "BloodMNIST",
#     "chestmnist": "ChestMNIST",
# }

# %%
# %run -tie multi_mnist.py --datasets breastmnist
# %reset -f
# Out:
# Current default figure size: [3.5, 2.625]
# New default figure size: [5.25, 3.9375]
# Available datasets: dict_keys(['mnist', 'fmnist'])
# Available medmnist datasets: dict_keys(['pathmnist', 'chestmnist', 'dermamnist', 'octmnist', 'pneumoniamnist', 'retinamnist', 'breastmnist', 'bloodmnist', 'tissuemnist', 'organamnist', 'organcmnist', 'organsmnist', 'organmnist3d', 'nodulemnist3d', 'adrenalmnist3d', 'fracturemnist3d', 'vesselmnist3d', 'synapsemnist3d'])
# Loading dataset:  breastmnist
# Using downloaded and verified file: /data1/deploy/polcanet/examples/notebooks/data/breastmnist/breastmnist.npz
# Using downloaded and verified file: /data1/deploy/polcanet/examples/notebooks/data/breastmnist/breastmnist.npz
# Dataset: breastmnist
# Train set: 546
# Test set: 156
# Saving Images: True, saving in path: /data1/deploy/polcanet/examples/notebooks/experiments/breastmnist_dataset
# 0.0 1.0
# (546, 28, 28) (156, 28, 28) (546, 28, 28) (156, 28, 28) (546, 1) (156, 1) None
# PolcaNet(
# ...

# %%
# %run -tn multi_mnist.py --datasets pneumoniamnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets retinamnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets dermamnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets octmnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets organamnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets organcmnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets organsmnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets pathmnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets pathmnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets bloodmnist
# %reset -f

# %%
# %run -tie multi_mnist.py --datasets chestmnist
# %reset -f
