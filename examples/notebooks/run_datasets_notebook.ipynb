# %% [markdown]
# ### Available Datasets:
# -     "mnist"
# -     "breastmnist"
# -     "dermamnist"
# -     "octmnist"
# -     "organamnist"
# -     "organcmnist"
# -     "organsmnist"
# -     "pathmnist"
# -     "pneumoniamnist"
# -     "retinamnist"
# -     "bloodmnist"
# -     "chestmnist"

# %%
# %run -tie train_datasets.py --datasets mnist
# %reset -f
# Out:
# Available datasets: dict_keys(['mnist', 'fmnist', 'cifar10'])
# Available medmnist datasets: dict_keys(['pathmnist', 'chestmnist', 'dermamnist', 'octmnist', 'pneumoniamnist', 'retinamnist', 'breastmnist', 'bloodmnist', 'tissuemnist', 'organamnist', 'organcmnist', 'organsmnist', 'organmnist3d', 'nodulemnist3d', 'adrenalmnist3d', 'fracturemnist3d', 'vesselmnist3d', 'synapsemnist3d'])
# Loading dataset:  mnist
# Dataset: mnist
# Train set: 60000
# Test set: 10000
# Data shape, train: (60000, 28, 28), test: (10000, 28, 28)
# Saving Images: True, saving in path: /data1/deploy/polcanet/examples/notebooks/experiments/mnist_dataset
# 0.0 1.0
# (60000, 28, 28) (10000, 28, 28) (60000, 28, 28) (10000, 28, 28) torch.Size([60000]) torch.Size([10000]) None
# PolcaNet(
#   (encoder): EncoderWrapper(
#     (encoder): ConvEncoder(
#       (encoder): Sequential(
#         (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): SiLU()
#         (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (3): SiLU()
#         (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (5): SiLU()
#         (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (7): SiLU()
#         (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (9): SiLU()
#         (10): Flatten(start_dim=1, end_dim=-1)
#         (11): Linear(in_features=128, out_features=112, bias=True)
#         (12): SiLU()
#         (13): Linear(in_features=112, out_features=28, bias=True)
#       )
#     )
#     (post_encoder): Sequential(
#       (0): Linear(in_features=28, out_features=28, bias=False)
#       (1): Softsign()
#     )
#   )
#   (decoder): LinearDecoder(
#     (decoder): Sequential(
#       (0): Linear(in_features=28, out_features=512, bias=False)
#       (1): SiLU()
#       (2): Linear(in_features=512, out_features=512, bias=False)
#       (3): SiLU()
#       (4): Linear(in_features=512, out_features=512, bias=False)
#       (5): SiLU()
#       (6): Linear(in_features=512, out_features=512, bias=False)
#       (7): SiLU()
#       (8): Linear(in_features=512, out_features=784, bias=False)
#     )
#   )
#   (polca_loss): PolcaNetLoss()
# )
# ========================================================================================
# Layer (type (var_name))                  Kernel Shape     Output Shape     Param #
# ========================================================================================
# PolcaNet (PolcaNet)                      --               [1, 28]          --
# ├─EncoderWrapper (encoder)               --               [1, 28]          --
# │    └─ConvEncoder (encoder)             --               [1, 28]          --
# │    │    └─Sequential (encoder)         --               [1, 28]          115,852
# │    └─Sequential (post_encoder)         --               [1, 28]          --
# │    │    └─Linear (0)                   --               [1, 28]          784
# │    │    └─Softsign (1)                 --               [1, 28]          --
# ├─LinearDecoder (decoder)                --               [1, 28, 28]      --
# │    └─Sequential (decoder)              --               [1, 784]         --
# │    │    └─Linear (0)                   --               [1, 512]         14,336
# │    │    └─SiLU (1)                     --               [1, 512]         --
# │    │    └─Linear (2)                   --               [1, 512]         262,144
# │    │    └─SiLU (3)                     --               [1, 512]         --
# │    │    └─Linear (4)                   --               [1, 512]         262,144
# │    │    └─SiLU (5)                     --               [1, 512]         --
# │    │    └─Linear (6)                   --               [1, 512]         262,144
# │    │    └─SiLU (7)                     --               [1, 512]         --
# │    │    └─Linear (8)                   --               [1, 784]         401,408
# ========================================================================================
# Total params: 1,318,812
# Trainable params: 1,318,812
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.52
# ========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 5.28
# Estimated Total Size (MB): 5.33
# ========================================================================================
# epoch:   0%|          | 0/5000 [00:00<?, ?it/s]
# Final metrics at epoch: 5000
# Total Loss: 0.003303
# Reconstruction Loss: 0.003059
# Orthogonality Loss: 0.002036
# Center of Mass Loss: 0.00209
# Variance Reduction Loss: 0.000197
# epoch:   0%|          | 0/5000 [00:00<?, ?it/s]
# Final metrics at epoch: 5000
# Total Loss: 0.002908
# Reconstruction Loss: 0.002698
# Orthogonality Loss: 0.00185
# Center of Mass Loss: 0.001296
# Variance Reduction Loss: 0.0001237
# epoch:   0%|          | 0/5000 [00:00<?, ?it/s]
# Final metrics at epoch: 5000
# Total Loss: 0.002854
# Reconstruction Loss: 0.002645
# Orthogonality Loss: 0.00185
# Center of Mass Loss: 0.001241
# Variance Reduction Loss: 0.0001192
# Loss Interaction Analysis Report:
# Total interactions: 531000
# Total conflicts: 114996
# Overall conflict rate: 0.2166
#
# Pairwise Statistics (sorted by similarity):
# <style type="text/css">
# #T_d0748_row0_col5, #T_d0748_row0_col6 {
#   color: red;
# }
# #T_d0748_row1_col5, #T_d0748_row1_col6 {
#   color: coral;
# }
# #T_d0748_row2_col5, #T_d0748_row2_col6, #T_d0748_row3_col5, #T_d0748_row3_col6, #T_d0748_row4_col5, #T_d0748_row4_col6, #T_d0748_row5_col5, #T_d0748_row5_col6 {
#   color: green;
# }
# </style>
# <table id="T_d0748">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0748_level0_col0" class="col_heading level0 col0" >loss1</th>
#       <th id="T_d0748_level0_col1" class="col_heading level0 col1" >loss2</th>
#       <th id="T_d0748_level0_col2" class="col_heading level0 col2" >interactions</th>
#       <th id="T_d0748_level0_col3" class="col_heading level0 col3" >conflicts</th>
#       <th id="T_d0748_level0_col4" class="col_heading level0 col4" >conflict_rate</th>
#       <th id="T_d0748_level0_col5" class="col_heading level0 col5" >avg_similarity</th>
#       <th id="T_d0748_level0_col6" class="col_heading level0 col6" >relationship</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0748_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0748_row0_col0" class="data row0 col0" >com</td>
#       <td id="T_d0748_row0_col1" class="data row0 col1" >var</td>
#       <td id="T_d0748_row0_col2" class="data row0 col2" >88500</td>
#       <td id="T_d0748_row0_col3" class="data row0 col3" >88388</td>
#       <td id="T_d0748_row0_col4" class="data row0 col4" >0.999</td>
#       <td id="T_d0748_row0_col5" class="data row0 col5" >-0.892</td>
#       <td id="T_d0748_row0_col6" class="data row0 col6" >Strongly Conflicting</td>
#     </tr>
#     <tr>
#       <th id="T_d0748_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0748_row1_col0" class="data row1 col0" >rec</td>
#       <td id="T_d0748_row1_col1" class="data row1 col1" >com</td>
#       <td id="T_d0748_row1_col2" class="data row1 col2" >88500</td>
#       <td id="T_d0748_row1_col3" class="data row1 col3" >7353</td>
#       <td id="T_d0748_row1_col4" class="data row1 col4" >0.083</td>
#       <td id="T_d0748_row1_col5" class="data row1 col5" >-0.002</td>
#       <td id="T_d0748_row1_col6" class="data row1 col6" >Weakly Conflicting</td>
#     </tr>
#     <tr>
#       <th id="T_d0748_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0748_row2_col0" class="data row2 col0" >ort</td>
#       <td id="T_d0748_row2_col1" class="data row2 col1" >var</td>
#       <td id="T_d0748_row2_col2" class="data row2 col2" >88500</td>
#       <td id="T_d0748_row2_col3" class="data row2 col3" >6070</td>
#       <td id="T_d0748_row2_col4" class="data row2 col4" >0.069</td>
#       <td id="T_d0748_row2_col5" class="data row2 col5" >0.003</td>
#       <td id="T_d0748_row2_col6" class="data row2 col6" >Weakly Cooperative</td>
#     </tr>
#     <tr>
#       <th id="T_d0748_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0748_row3_col0" class="data row3 col0" >rec</td>
#       <td id="T_d0748_row3_col1" class="data row3 col1" >var</td>
#       <td id="T_d0748_row3_col2" class="data row3 col2" >88500</td>
#       <td id="T_d0748_row3_col3" class="data row3 col3" >3843</td>
#       <td id="T_d0748_row3_col4" class="data row3 col4" >0.043</td>
#       <td id="T_d0748_row3_col5" class="data row3 col5" >0.003</td>
#       <td id="T_d0748_row3_col6" class="data row3 col6" >Weakly Cooperative</td>
#     </tr>
#     <tr>
#       <th id="T_d0748_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0748_row4_col0" class="data row4 col0" >ort</td>
#       <td id="T_d0748_row4_col1" class="data row4 col1" >com</td>
#       <td id="T_d0748_row4_col2" class="data row4 col2" >88500</td>
#       <td id="T_d0748_row4_col3" class="data row4 col3" >4126</td>
#       <td id="T_d0748_row4_col4" class="data row4 col4" >0.047</td>
#       <td id="T_d0748_row4_col5" class="data row4 col5" >0.046</td>
#       <td id="T_d0748_row4_col6" class="data row4 col6" >Weakly Cooperative</td>
#     </tr>
#     <tr>
#       <th id="T_d0748_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d0748_row5_col0" class="data row5 col0" >rec</td>
#       <td id="T_d0748_row5_col1" class="data row5 col1" >ort</td>
#       <td id="T_d0748_row5_col2" class="data row5 col2" >88500</td>
#       <td id="T_d0748_row5_col3" class="data row5 col3" >5216</td>
#       <td id="T_d0748_row5_col4" class="data row5 col4" >0.059</td>
#       <td id="T_d0748_row5_col5" class="data row5 col5" >0.090</td>
#       <td id="T_d0748_row5_col6" class="data row5 col6" >Weakly Cooperative</td>
#     </tr>
#   </tbody>
# </table>
# Mean Reconstruction Error: 0.0026
# Median Reconstruction Error: 0.0024
# Min Reconstruction Error: 0.0001
# Max Reconstruction Error: 0.0130
#     Orthogonality Test Analysis
#     ============================
#
#     This report analyzes the orthogonality of the latent features generated by the autoencoder.
#     We used a sample size of 1000 randomly selected data points for the analysis.
#
#     The orthogonality of the features is assessed by minimizing the cosine distance between the
#     latent features. The cosine similarity values between the features are summarized below:
#
#     - Mean cosine similarity: -0.0001
#     - Max cosine similarity: 0.0860
#     - Min cosine similarity: -0.0883
#     Variance Test Analysis
#     =======================
#
#     This report analyzes the variance concentration of the latent features generated by the autoencoder.
#     We used a sample size of 1000 randomly selected data points for the analysis.
#
#     The variance concentration of the features is assessed by minimizing the center of mass of the
#     latent space and fitting the variance distribution to an exponential distribution. The results
#     are summarized below:
#
#     - Center of mass: 1.5495
#     - Variance fit to exponential distribution (sum of squared differences):
#      0.1363
# Mean Reconstruction Error: 0.0033
# Median Reconstruction Error: 0.0028
# Min Reconstruction Error: 0.0002
# Max Reconstruction Error: 0.0442
#     Orthogonality Test Analysis
#     ============================
#
#     This report analyzes the orthogonality of the latent features generated by the autoencoder.
#     We used a sample size of 1000 randomly selected data points for the analysis.
#
#     The orthogonality of the features is assessed by minimizing the cosine distance between the
#     latent features. The cosine similarity values between the features are summarized below:
#
#     - Mean cosine similarity: -0.0011
#     - Max cosine similarity: 0.0940
#     - Min cosine similarity: -0.1160
#     Variance Test Analysis
#     =======================
#
#     This report analyzes the variance concentration of the latent features generated by the autoencoder.
#     We used a sample size of 1000 randomly selected data points for the analysis.
#
#     The variance concentration of the features is assessed by minimizing the center of mass of the
#     latent space and fitting the variance distribution to an exponential distribution. The results
#     are summarized below:
#
#     - Center of mass: 1.5459
#     - Variance fit to exponential distribution (sum of squared differences):
#      0.1386
# output shape from pca (7000, 28) (3000, 28)
# output shape from POLCA (7000, 28) (3000, 28)
# Performance Metrics DataFrame:
#                      Accuracy       Error rate        Matthews       F1-Score  \
# Transformation            PCA POLCA        PCA  POLCA      PCA POLCA      PCA
# Classifier
# Gaussian Naive Bayes     0.84  0.89      16.20  11.00     0.82  0.88     0.84
# Linear SVM               0.88  0.94      12.37   6.00     0.86  0.93     0.87
# Logistic Regression      0.86  0.92      14.03   8.13     0.85  0.91     0.86
# Perceptron               0.78  0.75      22.03  25.00     0.76  0.73     0.77
# Ridge Classifier         0.81  0.89      18.93  10.70     0.79  0.88     0.80
#
#
# Transformation       POLCA
# Classifier
# Gaussian Naive Bayes  0.89
# Linear SVM            0.94
# Logistic Regression   0.92
# Perceptron            0.76
# Ridge Classifier      0.89
# Wilcoxon Signed-Rank Test Results DataFrame:
#            Wilcoxon Test P-Value Significant (p < 0.05)
# Accuracy             1.0   0.125       No better method
# Error rate           1.0   0.125       No better method
# Matthews             1.0   0.125       No better method
# F1-Score             1.0   0.125       No better method
#                        NMSE     PSNR     SSI
# Method
# POLCA mnist_dataset  0.1656  25.7782  0.9406
# PCA mnist_dataset    0.4118  17.6297  0.6405
# Done
#
# IPython CPU timings (estimated):
#   User   :   18095.92 s.
#   System :   57772.25 s.
# Wall time:    8380.54 s.

# %%
# %run -tie train_datasets.py --datasets fmnist
# %reset -f
# Out:
# Current default figure size: [3.5, 2.625]
# New default figure size: [5.25, 3.9375]
# Available datasets: dict_keys(['mnist', 'fmnist', 'cifar10'])
# Available medmnist datasets: dict_keys(['pathmnist', 'chestmnist', 'dermamnist', 'octmnist', 'pneumoniamnist', 'retinamnist', 'breastmnist', 'bloodmnist', 'tissuemnist', 'organamnist', 'organcmnist', 'organsmnist', 'organmnist3d', 'nodulemnist3d', 'adrenalmnist3d', 'fracturemnist3d', 'vesselmnist3d', 'synapsemnist3d'])
# Loading dataset:  fmnist
# Dataset: fmnist
# Train set: 60000
# Test set: 10000
# Data shape, train: (60000, 28, 28), test: (10000, 28, 28)
# Saving Images: True, saving in path: /data1/deploy/polcanet/examples/notebooks/experiments/fmnist_dataset
# 0.0 1.0
# (60000, 28, 28) (10000, 28, 28) (60000, 28, 28) (10000, 28, 28) torch.Size([60000]) torch.Size([10000]) None
# PolcaNet(
#   (encoder): EncoderWrapper(
#     (encoder): ConvEncoder(
#       (encoder): Sequential(
#         (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): SiLU()
#         (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (3): SiLU()
#         (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (5): SiLU()
#         (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (7): SiLU()
#         (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (9): SiLU()
#         (10): Flatten(start_dim=1, end_dim=-1)
#         (11): Linear(in_features=128, out_features=112, bias=True)
#         (12): SiLU()
#         (13): Linear(in_features=112, out_features=28, bias=True)
#       )
#     )
#     (post_encoder): Sequential(
#       (0): Linear(in_features=28, out_features=28, bias=False)
#       (1): Softsign()
#     )
#   )
#   (decoder): LinearDecoder(
#     (decoder): Sequential(
#       (0): Linear(in_features=28, out_features=512, bias=False)
#       (1): SiLU()
#       (2): Linear(in_features=512, out_features=512, bias=False)
#       (3): SiLU()
#       (4): Linear(in_features=512, out_features=512, bias=False)
#       (5): SiLU()
#       (6): Linear(in_features=512, out_features=512, bias=False)
#       (7): SiLU()
#       (8): Linear(in_features=512, out_features=784, bias=False)
#     )
#   )
#   (polca_loss): PolcaNetLoss()
# )
# ========================================================================================
# Layer (type (var_name))                  Kernel Shape     Output Shape     Param #
# ========================================================================================
# PolcaNet (PolcaNet)                      --               [1, 28]          --
# ├─EncoderWrapper (encoder)               --               [1, 28]          --
# │    └─ConvEncoder (encoder)             --               [1, 28]          --
# │    │    └─Sequential (encoder)         --               [1, 28]          115,852
# │    └─Sequential (post_encoder)         --               [1, 28]          --
# │    │    └─Linear (0)                   --               [1, 28]          784
# │    │    └─Softsign (1)                 --               [1, 28]          --
# ├─LinearDecoder (decoder)                --               [1, 28, 28]      --
# │    └─Sequential (decoder)              --               [1, 784]         --
# │    │    └─Linear (0)                   --               [1, 512]         14,336
# │    │    └─SiLU (1)                     --               [1, 512]         --
# │    │    └─Linear (2)                   --               [1, 512]         262,144
# │    │    └─SiLU (3)                     --               [1, 512]         --
# │    │    └─Linear (4)                   --               [1, 512]         262,144
# │    │    └─SiLU (5)                     --               [1, 512]         --
# │    │    └─Linear (6)                   --               [1, 512]         262,144
# │    │    └─SiLU (7)                     --               [1, 512]         --
# │    │    └─Linear (8)                   --               [1, 784]         401,408
# ========================================================================================
# Total params: 1,318,812
# Trainable params: 1,318,812
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.52
# ========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 5.28
# Estimated Total Size (MB): 5.33
# ========================================================================================
# epoch:   0%|          | 0/5000 [00:00<?, ?it/s]
# Final metrics at epoch: 5000
# Total Loss: 0.006409
# Reconstruction Loss: 0.006176
# Orthogonality Loss: 0.0019
# Center of Mass Loss: 0.002166
# Variance Reduction Loss: 0.0002092
# epoch:   0%|          | 0/5000 [00:00<?, ?it/s]
# Final metrics at epoch: 5000
# Total Loss: 0.005939
# Reconstruction Loss: 0.005749
# Orthogonality Loss: 0.001632
# Center of Mass Loss: 0.001391
# Variance Reduction Loss: 0.0001327
# epoch:   0%|          | 0/5000 [00:00<?, ?it/s]
# Final metrics at epoch: 5000
# Total Loss: 0.005867
# Reconstruction Loss: 0.005681
# Orthogonality Loss: 0.001602
# Center of Mass Loss: 0.001332
# Variance Reduction Loss: 0.0001278
# Loss Interaction Analysis Report:
# Total interactions: 531000
# Total conflicts: 115918
# Overall conflict rate: 0.2183
#
# Pairwise Statistics (sorted by similarity):
# <style type="text/css">
# #T_cbf16_row0_col5, #T_cbf16_row0_col6 {
#   color: red;
# }
# #T_cbf16_row1_col5, #T_cbf16_row1_col6, #T_cbf16_row2_col5, #T_cbf16_row2_col6 {
#   color: coral;
# }
# #T_cbf16_row3_col5, #T_cbf16_row3_col6, #T_cbf16_row4_col5, #T_cbf16_row4_col6, #T_cbf16_row5_col5, #T_cbf16_row5_col6 {
#   color: green;
# }
# </style>
# <table id="T_cbf16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbf16_level0_col0" class="col_heading level0 col0" >loss1</th>
#       <th id="T_cbf16_level0_col1" class="col_heading level0 col1" >loss2</th>
#       <th id="T_cbf16_level0_col2" class="col_heading level0 col2" >interactions</th>
#       <th id="T_cbf16_level0_col3" class="col_heading level0 col3" >conflicts</th>
#       <th id="T_cbf16_level0_col4" class="col_heading level0 col4" >conflict_rate</th>
#       <th id="T_cbf16_level0_col5" class="col_heading level0 col5" >avg_similarity</th>
#       <th id="T_cbf16_level0_col6" class="col_heading level0 col6" >relationship</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbf16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbf16_row0_col0" class="data row0 col0" >com</td>
#       <td id="T_cbf16_row0_col1" class="data row0 col1" >var</td>
#       <td id="T_cbf16_row0_col2" class="data row0 col2" >88500</td>
#       <td id="T_cbf16_row0_col3" class="data row0 col3" >88320</td>
#       <td id="T_cbf16_row0_col4" class="data row0 col4" >0.998</td>
#       <td id="T_cbf16_row0_col5" class="data row0 col5" >-0.682</td>
#       <td id="T_cbf16_row0_col6" class="data row0 col6" >Strongly Conflicting</td>
#     </tr>
#     <tr>
#       <th id="T_cbf16_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbf16_row1_col0" class="data row1 col0" >rec</td>
#       <td id="T_cbf16_row1_col1" class="data row1 col1" >com</td>
#       <td id="T_cbf16_row1_col2" class="data row1 col2" >88500</td>
#       <td id="T_cbf16_row1_col3" class="data row1 col3" >12639</td>
#       <td id="T_cbf16_row1_col4" class="data row1 col4" >0.143</td>
#       <td id="T_cbf16_row1_col5" class="data row1 col5" >-0.012</td>
#       <td id="T_cbf16_row1_col6" class="data row1 col6" >Weakly Conflicting</td>
#     </tr>
#     <tr>
#       <th id="T_cbf16_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cbf16_row2_col0" class="data row2 col0" >ort</td>
#       <td id="T_cbf16_row2_col1" class="data row2 col1" >var</td>
#       <td id="T_cbf16_row2_col2" class="data row2 col2" >88500</td>
#       <td id="T_cbf16_row2_col3" class="data row2 col3" >1949</td>
#       <td id="T_cbf16_row2_col4" class="data row2 col4" >0.022</td>
#       <td id="T_cbf16_row2_col5" class="data row2 col5" >-0.000</td>
#       <td id="T_cbf16_row2_col6" class="data row2 col6" >Weakly Conflicting</td>
#     </tr>
#     <tr>
#       <th id="T_cbf16_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cbf16_row3_col0" class="data row3 col0" >rec</td>
#       <td id="T_cbf16_row3_col1" class="data row3 col1" >var</td>
#       <td id="T_cbf16_row3_col2" class="data row3 col2" >88500</td>
#       <td id="T_cbf16_row3_col3" class="data row3 col3" >8454</td>
#       <td id="T_cbf16_row3_col4" class="data row3 col4" >0.096</td>
#       <td id="T_cbf16_row3_col5" class="data row3 col5" >0.002</td>
#       <td id="T_cbf16_row3_col6" class="data row3 col6" >Weakly Cooperative</td>
#     </tr>
#     <tr>
#       <th id="T_cbf16_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cbf16_row4_col0" class="data row4 col0" >ort</td>
#       <td id="T_cbf16_row4_col1" class="data row4 col1" >com</td>
#       <td id="T_cbf16_row4_col2" class="data row4 col2" >88500</td>
#       <td id="T_cbf16_row4_col3" class="data row4 col3" >501</td>
#       <td id="T_cbf16_row4_col4" class="data row4 col4" >0.006</td>
#       <td id="T_cbf16_row4_col5" class="data row4 col5" >0.048</td>
#       <td id="T_cbf16_row4_col6" class="data row4 col6" >Weakly Cooperative</td>
#     </tr>
#     <tr>
#       <th id="T_cbf16_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cbf16_row5_col0" class="data row5 col0" >rec</td>
#       <td id="T_cbf16_row5_col1" class="data row5 col1" >ort</td>
#       <td id="T_cbf16_row5_col2" class="data row5 col2" >88500</td>
#       <td id="T_cbf16_row5_col3" class="data row5 col3" >4055</td>
#       <td id="T_cbf16_row5_col4" class="data row5 col4" >0.046</td>
#       <td id="T_cbf16_row5_col5" class="data row5 col5" >0.074</td>
#       <td id="T_cbf16_row5_col6" class="data row5 col6" >Weakly Cooperative</td>
#     </tr>
#   </tbody>
# </table>
# Mean Reconstruction Error: 0.0057
# Median Reconstruction Error: 0.0044
# Min Reconstruction Error: 0.0004
# Max Reconstruction Error: 0.0585
#     Orthogonality Test Analysis
#     ============================
#
#     This report analyzes the orthogonality of the latent features generated by the autoencoder.
#     We used a sample size of 1000 randomly selected data points for the analysis.
#
#     The orthogonality of the features is assessed by minimizing the cosine distance between the
#     latent features. The cosine similarity values between the features are summarized below:
#
#     - Mean cosine similarity: 0.0000
#     - Max cosine similarity: 0.0824
#     - Min cosine similarity: -0.1075
#     Variance Test Analysis
#     =======================
#
#     This report analyzes the variance concentration of the latent features generated by the autoencoder.
#     We used a sample size of 1000 randomly selected data points for the analysis.
#
#     The variance concentration of the features is assessed by minimizing the center of mass of the
#     latent space and fitting the variance distribution to an exponential distribution. The results
#     are summarized below:
#
#     - Center of mass: 1.5321
#     - Variance fit to exponential distribution (sum of squared differences):
#      0.1389
# Mean Reconstruction Error: 0.0074
# Median Reconstruction Error: 0.0049
# Min Reconstruction Error: 0.0004
# Max Reconstruction Error: 0.2300
#     Orthogonality Test Analysis
#     ============================
#
#     This report analyzes the orthogonality of the latent features generated by the autoencoder.
#     We used a sample size of 1000 randomly selected data points for the analysis.
#
#     The orthogonality of the features is assessed by minimizing the cosine distance between the
#     latent features. The cosine similarity values between the features are summarized below:
#
#     - Mean cosine similarity: 0.0007
#     - Max cosine similarity: 0.1316
#     - Min cosine similarity: -0.0889
#     Variance Test Analysis
#     =======================
#
#     This report analyzes the variance concentration of the latent features generated by the autoencoder.
#     We used a sample size of 1000 randomly selected data points for the analysis.
#
#     The variance concentration of the features is assessed by minimizing the center of mass of the
#     latent space and fitting the variance distribution to an exponential distribution. The results
#     are summarized below:
#
#     - Center of mass: 1.5475
#     - Variance fit to exponential distribution (sum of squared differences):
#      0.1369
# output shape from pca (7000, 28) (3000, 28)
# output shape from POLCA (7000, 28) (3000, 28)
# Performance Metrics DataFrame:
#                      Accuracy       Error rate        Matthews       F1-Score  \
# Transformation            PCA POLCA        PCA  POLCA      PCA POLCA      PCA
# Classifier
# Gaussian Naive Bayes     0.75  0.76      25.03  23.90     0.72  0.74     0.75
# Linear SVM               0.80  0.82      20.30  17.67     0.78  0.80     0.79
# Logistic Regression      0.79  0.81      21.47  18.80     0.76  0.79     0.78
# Perceptron               0.75  0.74      25.20  25.87     0.73  0.72     0.72
# Ridge Classifier         0.73  0.79      26.53  20.67     0.71  0.77     0.71
#
#
# Transformation       POLCA
# Classifier
# Gaussian Naive Bayes  0.76
# Linear SVM            0.82
# Logistic Regression   0.81
# Perceptron            0.73
# Ridge Classifier      0.79
# Wilcoxon Signed-Rank Test Results DataFrame:
#            Wilcoxon Test P-Value Significant (p < 0.05)
# Accuracy             1.5  0.1875       No better method
# Error rate           1.0   0.125       No better method
# Matthews             1.0   0.125       No better method
# F1-Score             0.0  0.0625       No better method
#                         NMSE     PSNR     SSI
# Method
# POLCA fmnist_dataset  0.2024  22.9838  0.7948
# PCA fmnist_dataset    0.3109  18.4598  0.6065
# Done
#
# IPython CPU timings (estimated):
#   User   :   18086.14 s.
#   System :   57782.70 s.
# Wall time:    8361.65 s.

# %%
# %run -tie train_datasets.py --datasets cifar10
# %reset -f
# Out:
# Available datasets: dict_keys(['mnist', 'fmnist', 'cifar10'])
# Available medmnist datasets: dict_keys(['pathmnist', 'chestmnist', 'dermamnist', 'octmnist', 'pneumoniamnist', 'retinamnist', 'breastmnist', 'bloodmnist', 'tissuemnist', 'organamnist', 'organcmnist', 'organsmnist', 'organmnist3d', 'nodulemnist3d', 'adrenalmnist3d', 'fracturemnist3d', 'vesselmnist3d', 'synapsemnist3d'])
# Loading dataset:  cifar10
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar10/cifar-10-python.tar.gz
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 170498071/170498071 [00:18<00:00, 9042917.13it/s]
# Extracting data/cifar10/cifar-10-python.tar.gz to data/cifar10
# Files already downloaded and verified
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /data1/deploy/polcanet/examples/notebooks/multi_mnist.py:307
#     305 # make a small dict with name, and class with the dataset name in parameters
#     306 if dataset_name in torch_datasets_dict:
# --> 307     train_on_torch_datasets(parameters)
#     308 else:
#     309     train_on_medmnist_datasets(parameters)
#
# File /data1/deploy/polcanet/examples/notebooks/multi_mnist.py:158, in train_on_torch_datasets(params)
#     155 def train_on_torch_datasets(params):
#     156     # first train without labels
#     157     for name in params.datasets:
# --> 158         train_set, test_set = get_torch_dataset(name)
#     159         print(f"Dataset: {name}")
#     160         print(f"Train set: {len(train_set)}")
#
# File /data1/deploy/polcanet/examples/notebooks/multi_mnist.py:216, in get_torch_dataset(name)
#     213 test_set = dataset(root=f"data/{name}", train=False, download=True, transform=None)
#     215 # convert to numpy
# --> 216 train_set.data = train_set.data.numpy()
#     217 test_set.data = test_set.data.numpy()
#     218 train_set.target = train_set.targets.numpy()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'numpy'
# IPython CPU timings (estimated):
#   User   :       2.42 s.
#   System :       0.91 s.
# Wall time:      23.31 s.

# %%
# %run -tie train_datasets.py --datasets breastmnist
# %reset -f

# %%
# %run -tn train_datasets.py --datasets pneumoniamnist
# %reset -f

# %%
# color
# %run -tie train_datasets.py --datasets retinamnist
# %reset -f

# %%
# color
# %run -tie train_datasets.py --datasets dermamnist
# %reset -f

# %%
# %run -tie train_datasets.py --datasets octmnist
# %reset -f

# %%
# %run -tie train_datasets.py --datasets organamnist
# %reset -f

# %%
# %run -tie train_datasets.py --datasets organcmnist
# %reset -f

# %%
# %run -tie train_datasets.py --datasets organsmnist
# %reset -f

# %%
# color
# %run -tie train_datasets.py --datasets pathmnist
# %reset -f

# %%
# color
# %run -tie train_datasets.py --datasets bloodmnist
# %reset -f

# %%
# %run -tie train_datasets.py --datasets chestmnist
# %reset -f
