# %% [markdown]
# # Run on all Datasets:

# %%
# %run train.py --list
# Out:
# mnist
# fmnist
# bent
# sinusoidal
# breastmnist
# dermamnist
# octmnist
# organamnist
# organcmnist
# organsmnist
# pathmnist
# pneumoniamnist
# retinamnist
# bloodmnist
# chestmnist
# tissuemnist

# %%
flags =" --batch_size 256 --n_updates 20000 --n_components 0.5 --size 64 --exp_dir experiments_10"

# %% [markdown]
# # sinusodial

# %%
# %run train.py --datasets sinusoidal {flags}
# Out:
# Loading dataset: sinusoidal
# Experiment configured with seed: 5, name: sinusoidal_dataset
# Experiment folder: /data1/deploy/polcanet/examples/notebooks/experiments_10/sinusoidal_dataset
# Saving Images: True, saving in path: /data1/deploy/polcanet/examples/notebooks/experiments_10/sinusoidal_dataset
# 'Data range: [2.980232238769531e-07, 0.9999992847442627]'
# 'Train dataset: (2000, 32, 32), Test dataset: (500, 32, 32)'
# 'Train targets: (2000,), Test labels: (500,)'
# 'Unique targets: None'
# 'Class labels: None'
# Number of components: 0.5
# PolcaNet(
#   (encoder): EncoderWrapper(
#     (encoder): ConvEncoder(
#       (encoder): Sequential(
#         (0): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (2): SiLU()
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (4): SiLU()
# ...

# %% [markdown]
# # bent

# %%
# %run train.py --datasets bent {flags}

# %% [markdown]
# # breastmnist

# %%
# %run train.py --datasets breastmnist {flags}

# %% [markdown]
# # pneumoniamnist

# %%
# %run train.py --datasets pneumoniamnist {flags}

# %% [markdown]
# # retinamnist (color)

# %%
# color
# %run train.py --datasets retinamnist {flags}

# %% [markdown]
# # dermamnist (color)

# %%
# color
# %run  train.py --datasets dermamnist {flags}

# %% [markdown]
# # octmnist

# %%
# %run train.py --datasets octmnist  {flags}

# %% [markdown]
# # organamnist

# %%
# %run train.py --datasets organamnist {flags}

# %% [markdown]
# # organcmnist

# %%
# %run train.py --datasets organcmnist {flags}

# %% [markdown]
# # organsmnist

# %%
# %run train.py --datasets organsmnist {flags}

# %% [markdown]
# # pathmnist (color)

# %%
# color
# %run train.py --datasets pathmnist {flags}

# %% [markdown]
# # bloodmnist (color)

# %%
# color
# %run train.py --datasets bloodmnist {flags}

# %% [markdown]
# # chestmnist

# %%
# %run train.py --datasets chestmnist {flags}

# %% [markdown]
# # tissuemnist

# %%
# %run train.py --datasets tissuemnist {flags}

# %% [markdown]
# # mnist

# %%
# %run train.py --datasets mnist {flags}

# %% [markdown]
# # fmnist

# %%
# %run train.py --datasets fmnist {flags}

# %% [markdown]
# # Save notebook as HTML with outputs

# %%
parameters.exp_dir

# %%
# !jupyter nbconvert --to HTML run_datasets_notebook.ipynb --output-dir {parameters.exp_dir}

# %% [markdown]
# ### END
