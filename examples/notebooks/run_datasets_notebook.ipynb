# %% [markdown]
# ### Run on all Datasets:

# %%
# %run train.py --list

# %%
flags =" --batch_size 128 --n_updates 20000 --n_components 0.5 --size 64 --exp_dir experiments_64x64_5_labels --with_labels"

# %%
# %run train.py --datasets sinusoidal {flags}

# %%
# %run train.py --datasets bent {flags}

# %%
# %run train.py --datasets breastmnist {flags}
# Out:
# Loading dataset: breastmnist
# Using downloaded and verified file: /data1/deploy/polcanet/examples/notebooks/data/breastmnist/breastmnist_64.npz
# Using downloaded and verified file: /data1/deploy/polcanet/examples/notebooks/data/breastmnist/breastmnist_64.npz
# Experiment configured with seed: 5, name: breastmnist_dataset_labels
# Experiment folder: /data1/deploy/polcanet/examples/notebooks/experiments_64x64_5_labels/breastmnist_dataset_labels
# Saving Images: True, saving in path: /data1/deploy/polcanet/examples/notebooks/experiments_64x64_5_labels/breastmnist_dataset_labels
# Data range: [0.0, 1.0]
# Train dataset: (546, 64, 64), Test dataset: (156, 64, 64)
# Train targets: (546, 1), Test labels: (156, 1)
# Unique targets: [0, 1]
# Class labels: {0: 'malignant', 1: 'normal, benign'}
# Class balance:
# malignant: 26.92%
# normal, benign: 73.08%
# Number of components: 0.5
# PolcaNet(
#   (encoder): EncoderWrapper(
#     (encoder): ConvEncoder(
#       (encoder): Sequential(
#         (0): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (2): GELU(approximate='none')
#         (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (4): GELU(approximate='none')
#         (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (6): GELU(approximate='none')
#         (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (8): GELU(approximate='none')
#         (9): Flatten(start_dim=1, end_dim=-1)
#         (10): Linear(in_features=8192, out_features=32, bias=True)
#         (11): GELU(approximate='none')
#         (12): Linear(in_features=32, out_features=8, bias=True)
#       )
#     )
#     (post_encoder): Sequential(
#       (0): Linear(in_features=8, out_features=8, bias=True)
#       (1): Linear(in_features=8, out_features=8, bias=True)
#       (2): Linear(in_features=8, out_features=8, bias=True)
#       (3): Tanh()
#     )
#     (classifier): Linear(in_features=8, out_features=2, bias=False)
#   )
#   (decoder): LinearDecoder(
#     (decoder): Sequential(
#       (0): Linear(in_features=8, out_features=1024, bias=False)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=1024, out_features=1024, bias=False)
#       (3): GELU(approximate='none')
#       (4): Linear(in_features=1024, out_features=4096, bias=False)
#     )
#   )
#   (polca_loss): PolcaNetLoss()
# )
# ========================================================================================
# Layer (type (var_name))                  Kernel Shape     Output Shape     Param #
# ========================================================================================
# PolcaNet (PolcaNet)                      --               [1, 8]           --
# ├─EncoderWrapper (encoder)               --               [1, 8]           --
# │    └─ConvEncoder (encoder)             --               [1, 8]           --
# │    │    └─Sequential (encoder)         --               [1, 8]           359,850
# │    └─Sequential (post_encoder)         --               [1, 8]           --
# │    │    └─Linear (0)                   --               [1, 8]           72
# │    │    └─Linear (1)                   --               [1, 8]           72
# │    │    └─Linear (2)                   --               [1, 8]           72
# │    │    └─Tanh (3)                     --               [1, 8]           --
# │    └─Linear (classifier)               --               [1, 2]           16
# ├─LinearDecoder (decoder)                --               [1, 64, 64]      --
# │    └─Sequential (decoder)              --               [1, 4096]        --
# │    │    └─Linear (0)                   --               [1, 1024]        8,192
# │    │    └─GELU (1)                     --               [1, 1024]        --
# │    │    └─Linear (2)                   --               [1, 1024]        1,048,576
# │    │    └─GELU (3)                     --               [1, 1024]        --
# │    │    └─Linear (4)                   --               [1, 4096]        4,194,304
# ========================================================================================
# Total params: 5,611,154
# Trainable params: 5,611,154
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 21.43
# ========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 1.07
# Params size (MB): 22.44
# Estimated Total Size (MB): 23.53
# ========================================================================================
# epoch:   0%|          | 0/4000 [00:00<?, ?it/s]

# %%
# %run train.py --datasets pneumoniamnist {flags}

# %%
# color
# %run train.py --datasets retinamnist {flags}

# %%
# color
# %run  train.py --datasets dermamnist {flags}

# %%
# %run train.py --datasets octmnist  {flags}

# %%
# %run train.py --datasets organamnist {flags}

# %%
# %run train.py --datasets organcmnist {flags}

# %%
# %run train.py --datasets organsmnist {flags}

# %%
# color
# %run train.py --datasets pathmnist {flags}

# %%
# color
# %run train.py --datasets bloodmnist {flags}

# %%
# %run train.py --datasets chestmnist {flags}

# %%
# %run train.py --datasets tissuemnist {flags}

# %%
# %run train.py --datasets mnist {flags}

# %%
# %run train.py --datasets fmnist {flags}

# %%
parameters.exp_dir

# %%
# !jupyter nbconvert --to HTML run_datasets_notebook.ipynb --output-dir {parameters.exp_dir}

# %% [markdown]
# ### END
