# %% [markdown]
# # **P**rincipal **O**rthogonal **L**atent **C**omponents **A**nalysis Net (POLCA-Net)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import display, clear_output
import ipywidgets as widgets
import matplotlib.pyplot as plt

# %%
import numpy as np
import torch
import torch.nn as nn
import torchinfo
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
import ipywidgets as widgets
from ipywidgets import fixed, interact, interact_manual, interactive

# %%
import polcanet.reports as report
import polcanet.utils as ut
import polcanet.mlutils as mlut
from polcanet import PolcaNet

# %%
import random

random_seed = 5
np.random.seed(random_seed)
torch.manual_seed(random_seed)
random.seed(random_seed)

torch.autograd.set_detect_anomaly(False)
torch.autograd.profiler.profile(False)
torch.autograd.profiler.emit_nvtx(False)
print('CUDA available:', torch.cuda.is_available())
print('cuDNN version:', torch.backends.cudnn.version())
print('cuDNN enabled:', torch.backends.cudnn.enabled)
# Out:
# CUDA available: True
# cuDNN version: 90100
# cuDNN enabled: True

# %% [markdown]
# ### Set with or without classification Labels

# %%
with_labels = False

# %%
if with_labels:
    name = "FMNIST_dataset_labels"
else:
    name = "FMNIST_dataset"
    
exp = ut.ExperimentInfoHandler(
    name=name,
    description="POLCA-Net on MNIST dataset",
    random_seed=random_seed,
)
ut.set_save_fig(True)
ut.set_save_path(str(exp.get_experiment_folder()))
print(f"Saving data: {ut.get_save_fig()}, saving in path: {ut.get_save_path()}")
# Out:
# Saving data: True, saving in path: /data1/deploy/polcanet/examples/notebooks/output/experiments/FMNIST_dataset

# %% [markdown]
# ### Load dataset

# %%
from torchvision.datasets import FashionMNIST
mnist_trainset = FashionMNIST(root="data/FMNIST", train=True, download=True, transform=None)
mnist_testset = FashionMNIST(root="data/FMNIST", train=False, download=True, transform=None)

# %%
train_dataset = mnist_trainset.data.reshape(-1, 28, 28) / 255.0
eval_dataset = mnist_testset.data.reshape(-1, 28, 28) / 255.0
y = mnist_trainset.targets.numpy()
y_test = mnist_testset.targets.numpy()

labels = np.unique(y) if with_labels else None

X = np.array(train_dataset.numpy(), dtype=np.float32)
X = np.squeeze(X)
print(X.min(),X.max())
X_test = np.array(eval_dataset.numpy(), dtype=np.float32)
X_test = np.squeeze(X_test)
train_dataset.shape, eval_dataset.shape, X.shape,X_test.shape, y.shape, y_test.shape, labels
# Out:
# 0.0 1.0
# (torch.Size([60000, 28, 28]),
#  torch.Size([10000, 28, 28]),
#  (60000, 28, 28),
#  (10000, 28, 28),
#  (60000,),
#  (10000,),
#  None)

# %%
def random_sample(x,y=None,n=1000):
    indices = np.random.choice(x.shape[0], min(x.shape[0],n), replace=False)
    if y is None:
        return x[indices]
    return x[indices], y[indices]

# %%
X,y = random_sample(X, y ,12000)
X_test, y_test = random_sample(X_test, y_test ,3000)
X.shape,X_test.shape, y.shape, y_test.shape
# Out:
# ((12000, 28, 28), (3000, 28, 28), (12000,), (3000,))

# %%
ut.set_fig_prefix("sin_train")
ut.plot_train_images(X, "MNIST train dataset images",cmap="gray", n=5)
ut.set_fig_prefix("sin_test")
ut.plot_train_images(X_test, "MNIST test dataset images",cmap="gray", n=5)

# %% [markdown]
# ### Fit standard sklearn PCA

# %%
n_components = 11 #  Heuristic sqrt(image size)
pca = ut.perform_pca(X, n_components=n_components, title="PCA on MNIST dataset dataset")
Xpca = pca.transform(np.squeeze(X.reshape(X.shape[0], -1)))
plt.show()

# %% [markdown]
# ### Fit POLCANet

# %%
N = X[0].shape[0]
M = X[0].shape[1]

# %%
import polcanet.aencoders as pae

act_fn = torch.nn.SiLU
input_dim = (N, M)
latent_dim = pca.n_components
assert N == input_dim[0], "input_dim[0] should match first matrix dimension N"
assert M == input_dim[1], "input_dim[1] should match second matrix dimension M"


encoder = pae.ConvEncoder(
    input_channels=1,
    latent_dim=latent_dim,
    conv_dim=2,
    initial_channels=16,
    growth_factor=2,
    num_layers=6,
    act_fn=act_fn,
    size=N,
)

decoder = pae.LinearDecoder(
    latent_dim=latent_dim,
    input_dim=input_dim,
    hidden_dim=8 * 256,
    num_layers=3,
    act_fn=nn.GELU,
    bias=False,
)



decoder =  pae.LinearConvDecoder(
    latent_dim=latent_dim,
    hidden_sizes=[64, 128, 256, 256],  
    output_dim=input_dim,   
    act_fn=nn.GELU,
    bias = False,
)

model = PolcaNet(
    encoder=encoder,
    decoder=decoder,
    latent_dim=latent_dim,
    r=1,  # reconstruction loss weight
    c=1e-1 if with_labels else 0,  # classification loss (cross ent) weight
    alpha=1e-1 if with_labels else 1,  # ortgogonality loss
    beta=1e-1 if with_labels else 1,  # variance sorting loss
    gamma=0,  # variance reduction loss
    class_labels=labels,  # class labels for supervised in case labels is not None
    std_noise=0.0,
    blend_prob = 0.5,
)

print(model)
print("X[0:1] shape",torch.as_tensor(X[:1]).shape)
summary = torchinfo.summary(
    model,
    input_data = torch.as_tensor(X[:1]),
    dtypes=[torch.float32],
    verbose=1,
    col_width=16,
    col_names=["kernel_size", "output_size", "num_params"],
    row_settings=["var_names"],
    depth=1,
)
ut.save_text(str(model), "model.txt")
ut.save_text(str(summary), "model_summary.txt")
# Out:
# PolcaNet(
#   (encoder): EncoderWrapper(
#     (encoder): ConvEncoder(
#       (encoder): Sequential(
#         (0): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (2): SiLU()
#         (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (4): SiLU()
#         (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (6): SiLU()
#         (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (8): SiLU()
#         (9): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (10): SiLU()
#         (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (12): SiLU()
#         (13): Flatten(start_dim=1, end_dim=-1)
#         (14): Linear(in_features=512, out_features=11, bias=True)
#         (15): SiLU()
#       )
#     )
#     (polca_bottleneck): Sequential(
#       (0): Linear(in_features=11, out_features=11, bias=True)
#       (1): Softsign()
#     )
#   )
#   (decoder): LinearConvDecoder(
#     (act_fn): GELU(approximate='none')
#     (fc_layers): Sequential(
#       (0): Linear(in_features=11, out_features=64, bias=False)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=64, out_features=128, bias=False)
#       (3): GELU(approximate='none')
#       (4): Linear(in_features=128, out_features=256, bias=False)
#       (5): GELU(approximate='none')
#       (6): Linear(in_features=256, out_features=256, bias=False)
#       (7): GELU(approximate='none')
#       (8): Linear(in_features=256, out_features=4096, bias=False)
#       (9): GELU(approximate='none')
#     )
#     (conv_layers): Sequential(
#       (0): Upsample(scale_factor=2.0, mode='nearest')
#       (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): GELU(approximate='none')
#       (3): Upsample(scale_factor=2.0, mode='nearest')
#       (4): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (5): GELU(approximate='none')
#       (6): Upsample(scale_factor=2.0, mode='nearest')
#       (7): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (8): GELU(approximate='none')
#       (9): Upsample(size=(28, 28), mode='bilinear')
#       (10): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (polca_loss): PolcaNetLoss()
# )
# X[0:1] shape torch.Size([1, 28, 28])
# ========================================================================================
# Layer (type (var_name))                  Kernel Shape     Output Shape     Param #
# ========================================================================================
# PolcaNet (PolcaNet)                      --               [1, 11]          --
# ├─EncoderWrapper (encoder)               --               [1, 11]          1,578,513
# ├─LinearConvDecoder (decoder)            --               [28, 28]         1,543,136
# ========================================================================================
# Total params: 4,276,721
# Trainable params: 4,276,721
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 63.69
# ========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.71
# Params size (MB): 12.49
# Estimated Total Size (MB): 13.20
# ========================================================================================

# %%
model.to(device)
model.train_model(data=X, val_data=X_test,y=y, val_y=y_test,batch_size=512, num_epochs=50, report_freq=1, lr=1e-3)
# Out:
# epoch:   0%|          | 0/50 [00:00<?, ?it/s]
# Output()
# Final Train metrics at epoch: 50
# ========================================
# Total Loss: 0.01781
# Reconstruction Loss: 0.0117
# Orthogonality Loss: 0.004357
# Center of Mass Loss: 0.001753
#
# Final Validation metrics at epoch: 50
# ========================================
# Total Loss: 0.01541
# Reconstruction Loss: 0.01168
# Orthogonality Loss: 0.001893
# Center of Mass Loss: 0.001838

# %%
model.train_model(data=X, val_data=X_test,y=y, val_y=y_test,batch_size=512, num_epochs=25, report_freq=1, lr=1e-4)
# Out:
# epoch:   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Final Train metrics at epoch: 25
# ========================================
# Total Loss: 0.01346
# Reconstruction Loss: 0.01044
# Orthogonality Loss: 0.002248
# Center of Mass Loss: 0.0007661
#
# Final Validation metrics at epoch: 25
# ========================================
# Total Loss: 0.012
# Reconstruction Loss: 0.01047
# Orthogonality Loss: 0.0007362
# Center of Mass Loss: 0.000796

# %%
model.train_model(data=X, val_data=X_test,y=y, val_y=y_test,batch_size=512, num_epochs=25, report_freq=1, lr=1e-5)
# Out:
# epoch:   0%|          | 0/25 [00:00<?, ?it/s]
# Output()
# Final Train metrics at epoch: 25
# ========================================
# Total Loss: 0.01277
# Reconstruction Loss: 0.01028
# Orthogonality Loss: 0.001803
# Center of Mass Loss: 0.0006938
#
# Final Validation metrics at epoch: 25
# ========================================
# Total Loss: 0.01133
# Reconstruction Loss: 0.01034
# Orthogonality Loss: 0.0002704
# Center of Mass Loss: 0.0007254

# %% [markdown]
# ## Evaluate results

# %%
plt.figure()
z_score = model.mu.cpu() / model.std.cpu()
special_constant = np.argmax(z_score.abs())
plt.bar(range(latent_dim), z_score, label="std")
plt.title(f"Seek for special constant component: {special_constant} \n" + " max $z$-score: (high mean/very low std)" )
plt.show()
print("What does this component mean? an intercept? a dataset invariant?")
# Out:
# What does this component mean? an intercept? a dataset invariant?

# %% [markdown]
# ### Losses Interactions Analysis

# %%
ut.set_fig_prefix("train")
report.loss_interaction_analysis(model)
# Out:
# Loss Interaction Analysis Report:
# Total interactions: 115
# Total conflicts: 51
# Overall conflict rate: 0.4435
#
# Pairwise Statistics (sorted by similarity):
# <style type="text/css">
# #T_26bed_row0_col5, #T_26bed_row0_col6, #T_26bed_row1_col5, #T_26bed_row1_col6, #T_26bed_row2_col5, #T_26bed_row2_col6 {
#   color: green;
# }
# </style>
# <table id="T_26bed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26bed_level0_col0" class="col_heading level0 col0" >loss1</th>
#       <th id="T_26bed_level0_col1" class="col_heading level0 col1" >loss2</th>
#       <th id="T_26bed_level0_col2" class="col_heading level0 col2" >interactions</th>
#       <th id="T_26bed_level0_col3" class="col_heading level0 col3" >conflicts</th>
#       <th id="T_26bed_level0_col4" class="col_heading level0 col4" >conflict_rate</th>
#       <th id="T_26bed_level0_col5" class="col_heading level0 col5" >avg_similarity</th>
#       <th id="T_26bed_level0_col6" class="col_heading level0 col6" >relationship</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26bed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26bed_row0_col0" class="data row0 col0" >rec</td>
#       <td id="T_26bed_row0_col1" class="data row0 col1" >com</td>
#       <td id="T_26bed_row0_col2" class="data row0 col2" >115</td>
#       <td id="T_26bed_row0_col3" class="data row0 col3" >29</td>
#       <td id="T_26bed_row0_col4" class="data row0 col4" >0.2522</td>
#       <td id="T_26bed_row0_col5" class="data row0 col5" >0.0352</td>
#       <td id="T_26bed_row0_col6" class="data row0 col6" >Weakly Cooperative</td>
#     </tr>
#     <tr>
#       <th id="T_26bed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26bed_row1_col0" class="data row1 col0" >rec</td>
#       <td id="T_26bed_row1_col1" class="data row1 col1" >ort</td>
#       <td id="T_26bed_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_26bed_row1_col3" class="data row1 col3" >19</td>
#       <td id="T_26bed_row1_col4" class="data row1 col4" >0.1652</td>
#       <td id="T_26bed_row1_col5" class="data row1 col5" >0.1385</td>
#       <td id="T_26bed_row1_col6" class="data row1 col6" >Strongly Cooperative</td>
#     </tr>
#     <tr>
#       <th id="T_26bed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26bed_row2_col0" class="data row2 col0" >ort</td>
#       <td id="T_26bed_row2_col1" class="data row2 col1" >com</td>
#       <td id="T_26bed_row2_col2" class="data row2 col2" >115</td>
#       <td id="T_26bed_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_26bed_row2_col4" class="data row2 col4" >0.0261</td>
#       <td id="T_26bed_row2_col5" class="data row2 col5" >0.2300</td>
#       <td id="T_26bed_row2_col6" class="data row2 col6" >Strongly Cooperative</td>
#     </tr>
#   </tbody>
# </table>

# %%
ut.set_fig_prefix("train")
report.analyze_reconstruction_error(model, X)
ut.set_fig_prefix("test")
report.analyze_reconstruction_error(model, X_test)
# Out:
# Mean Reconstruction Error: 0.0229
# Median Reconstruction Error: 0.0196
# Min Reconstruction Error: 0.0037
# Max Reconstruction Error: 0.1086
# Mean Reconstruction Error: 0.0230
# Median Reconstruction Error: 0.0201
# Min Reconstruction Error: 0.0047
# Max Reconstruction Error: 0.1008

# %% [markdown]
# ### Reconstruction Analysis

# %%
latents, reconstructed = model.predict(X)

# %%
def plot_reconstruction(n_components):
    images = X[0:16]
    ut.plot_reconstruction_comparison(
        model,pca,images,cmap="gray",nrow=4, n_components=n_components)
    images = X_test[0:16]
    ut.plot_reconstruction_comparison(
        model,pca,images,cmap="gray",nrow=4, n_components=n_components)


interact(
    plot_reconstruction,
    n_components=widgets.IntSlider(min=1, max=pca.n_components, step=1, value=pca.n_components),
);
# Out:
# interactive(children=(IntSlider(value=11, description='n_components', max=11, min=1), Output()), _dom_classes=…

# %% [markdown]
# ### Orthogonality Analysis

# %%
o1 = widgets.Output()
o2 = widgets.Output()
with o1:
    print("TRAIN")
    ut.set_fig_prefix("train")
    report.orthogonality_test_analysis(model,pca, X)
with o2:
    print("TEST")
    ut.set_fig_prefix("test")
    report.orthogonality_test_analysis(model,pca, X_test)
    
layout = widgets.Layout(grid_template_columns="repeat(2, 600px)")
accordion = widgets.GridBox(children=[o1, o2], layout=layout)
display(accordion)
# Out:
# GridBox(children=(Output(), Output()), layout=Layout(grid_template_columns='repeat(2, 600px)'))

# %% [markdown]
# ### Variance Analysis

# %%
o1 = widgets.Output()
o2 = widgets.Output()
with o1:
    print("TRAIN")
    ut.set_fig_prefix("train")
    report.variance_test_analysis(model, X)
with o2:
    print("TEST")
    ut.set_fig_prefix("test")
    report.variance_test_analysis(model, X_test)
    
layout = widgets.Layout(grid_template_columns="repeat(2, 600px)")
accordion = widgets.GridBox(children=[o1, o2], layout=layout)
display(accordion)
# Out:
# GridBox(children=(Output(), Output()), layout=Layout(grid_template_columns='repeat(2, 600px)'))

# %% [markdown]
# ### Linear properties

# %%
ut.set_fig_prefix("train")
report.linearity_tests_analysis(model, X,alpha_min=0, num_samples=200)
ut.set_fig_prefix("test")
report.linearity_tests_analysis(model, X_test,alpha_min=0, num_samples=200)

# %% [markdown]
# ### 2D embeddings

# %%
def plot_embeddings(c_0=0,c_1=1):
    o1 = widgets.Output()
    o2 = widgets.Output()
    with o1:
        _, _ = ut.plot2d_analysis(Xpca, y, title="PCA transform", legend=True,c0=c_0,c1=c_1)
    with o2:
        _, _ = ut.plot2d_analysis(latents, y, title="POLCA-Net latent",  legend=True,c0=c_0,c1=c_1)
    layout = widgets.Layout(grid_template_columns="repeat(2, 600px)")
    accordion = widgets.GridBox(children=[o1, o2], layout=layout)
    display(accordion)
interact(plot_embeddings,c_0=(0,latents.shape[1]-1),c_1=(0,latents.shape[1]-1));
# Out:
# interactive(children=(IntSlider(value=0, description='c_0', max=10), IntSlider(value=1, description='c_1', max…

# %% [markdown]
# # Test Classification PCA vs. POLCA Net

# %%
def classify(n_components=pca.n_components):
    clear_output(wait=True)
    ut.make_classification_report(model, pca, X, y, X_test, y_test, n_components=n_components)


interactive(
    classify,
    n_components=widgets.IntSlider(min=1, max=pca.n_components, step=1, value=pca.n_components),
);

# %%
experiment_data = {
    "MNIST train": (
        X_test,
        model,
        pca,
    ),
    "MNIST test": (
        X,
        model,
        pca,
    ),
}
df_table = ut.image_metrics_table(experiment_data)
# Out:
#                      NMSE     PSNR     SSI
# Method
# POLCA MNIST train  0.3730  16.8924  0.5515
# PCA MNIST train    0.3760  16.7319  0.5043
# POLCA MNIST test   0.3701  16.9320  0.5521
# PCA MNIST test     0.3737  16.7542  0.5043

# %%
df_table.T
# Out:
# Method  POLCA MNIST train  PCA MNIST train  POLCA MNIST test  PCA MNIST test
# NMSE               0.3730           0.3760            0.3701          0.3737
# PSNR              16.8924          16.7319           16.9320         16.7542
# SSI                0.5515           0.5043            0.5521          0.5043
